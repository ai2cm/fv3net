# %%
cd ..
# Out:
# /home/noahb/fv3net

# %% [markdown]
# The fV3 data can be loaded with intake

# %% [markdown]
# # FV3 data
#
# This is hosted on this machine

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
data_2d = xr.open_zarr("/home/noahb/data/2019-07-17-GFDL_FV3_DYAMOND_0.25deg_15minute/2d.zarr/")

# %%
data_3d = xr.open_zarr("/home/noahb/data/2019-07-17-GFDL_FV3_DYAMOND_0.25deg_15minute/3d.zarr/")

# %%
data_2d
# Out:
# <xarray.Dataset>
# Dimensions:       (bnds: 2, grid_xt: 1536, grid_yt: 768, time: 48)
# Coordinates:
#   * grid_xt       (grid_xt) float32 0.1171875 0.3515625 ... 359.64844 359.8828
#   * grid_yt       (grid_yt) float32 -89.88281 -89.64844 ... 89.64844 89.88281
#   * time          (time) object 2016-08-01 00:15:00 ... 2016-08-01 12:00:00
# Dimensions without coordinates: bnds
# Data variables:
#     cape          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     cin           (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     cldc          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     flds          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     flus          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     flut          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     fsds          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     fsdt          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     fsus          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     fsut          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     grid_xt_bnds  (grid_xt, bnds) float32 dask.array<shape=(1536, 2), chunksize=(1536, 2)>
#     grid_yt_bnds  (grid_yt, bnds) float32 dask.array<shape=(768, 2), chunksize=(768, 2)>
#     h500          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     intqg         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     intqi         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     intql         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     intqr         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     intqs         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     intqv         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     lhflx         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     pr            (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     ps            (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     q2m           (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     qs            (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     rh500         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     rh700         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     rh850         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     shflx         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     t2m           (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     ts            (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     u10m          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     u200          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     ustrs         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     v10m          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     v200          (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
#     vstrs         (time, grid_yt, grid_xt) float32 dask.array<shape=(48, 768, 1536), chunksize=(48, 768, 1536)>
# Attributes:
#     code_version:  $Name: bronx-10_performance_z1l $
#     filename:      cape_15min.tile1.nc
#     grid_tile:     N/A
#     grid_type:     regular
#     history:       fregrid --format netcdf4_classic --input_file /work/James....
#     title:         20160801.00Z.C3072.32bit

# %%
plt.figure(figsize=(10, 5))
data_2d.intqv[0].plot()
