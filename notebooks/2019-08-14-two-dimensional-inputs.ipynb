# %%
from src.data import open_data

# %%
src = open_data(sources=True)
src
# Out:
# <xarray.Dataset>
# Dimensions:       (bnds: 2, grid_xt: 1536, grid_yt: 768, pfull: 79, time: 4)
# Coordinates:
#   * time          (time) object 2016-08-01 03:00:00 ... 2016-08-01 12:00:00
#   * grid_xt       (grid_xt) float32 0.1171875 0.3515625 ... 359.64844 359.8828
#   * grid_yt       (grid_yt) float32 -89.88281 -89.64844 ... 89.64844 89.88281
#   * pfull         (pfull) float32 4.5137978 8.300872 ... 994.3374 998.2764
# Dimensions without coordinates: bnds
# Data variables:
#     dqv           (time, pfull, grid_yt, grid_xt) float32 dask.array<shape=(4, 79, 768, 1536), chunksize=(1, 79, 256, 256)>
#     dtemp         (time, pfull, grid_yt, grid_xt) float32 dask.array<shape=(4, 79, 768, 1536), chunksize=(1, 79, 256, 256)>
#     grid_xt_bnds  (grid_xt, bnds) float32 dask.array<shape=(1536, 2), chunksize=(256, 2)>
#     grid_yt_bnds  (grid_yt, bnds) float32 dask.array<shape=(768, 2), chunksize=(256, 2)>
# ...

# %% [markdown]
# # Downwelling SW (insolation)

# %%
src.fsdt[0].plot()

# %%
src.fsdt[-1].plot()

# %% [markdown]
# # Surface fluxes

# %%
src.lhflx[0].plot()

# %%
src.lhflx[0].plot()
