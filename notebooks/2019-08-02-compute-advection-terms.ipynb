# %%
cd ../
# Out:
# /home/noahb/fv3net

# %%
from scipy.interpolate import interp1d
from metpy.interpolate import interpolate_1d
from src.data.regrid import height_on_model_levels
import xarray as xr
import matplotlib.pyplot as plt

# %%
data_2d = xr.open_zarr("/home/noahb/data/2019-07-17-GFDL_FV3_DYAMOND_0.25deg_15minute/2d.zarr/")
data_3d = xr.open_zarr("/home/noahb/data/2019-07-17-GFDL_FV3_DYAMOND_0.25deg_15minute/3d.zarr/")

# %%
data_3d = data_3d.isel(time=slice(0, 1)).load()

# %%
h_pfull = height_on_model_levels(data_3d)

# %%
h_pfull[0,...,-1].plot(vmin=0)

# %%
h_pfull.isel(pfull=0, time=0).plot()

# %%
z = np.exp(np.)

# %%
x,y = xr.broadcast(h_pfull, data_3d.qv)
heights = interpolate_1d(z.values, x.values, y.values, axis=x.get_axis_num('pfull'))

# %%
dims = ['time', 'grid_yt', 'grid_xt', 'z']
coords = {dim: h_pfull[dim] for dim in dims if dim in h_pfull}
coords['z'] = z

interped = xr.DataArray(heights, dims=['time', 'grid_yt', 'grid_xt', 'z'], coords=coords)

# %%
interped.isel(grid_xt=0, time=0).plot.contourf(x='grid_yt'a
                                              )

# %%
interped = xr.DataArray(heights, dims=['time', 'grid_yt', 'grid_xt', 'z'], coords=coords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-bfb480553513> in <module>
# ----> 1 interped = xr.DataArray(heights, dims=['time', 'grid_yt', 'grid_xt', 'z'], coords=coords)
#
# NameError: name 'coords' is not defined
